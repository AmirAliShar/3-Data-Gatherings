# %% [markdown]
# # JSON --> JAVA script on notation
# **It is universal daat format.It is fetch from API.**
# # SQL --> Structure query language
# **Directly download the data from database(Kaggle).**

# %%
import pandas as pd
#Remove the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Working with JSON

# %%
json=pd.read_json("train.json")
json.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
# Take JSON  data from URL
pd.read_json("http://www.floatrates.com/daily/usd.json")
# Out:
#                                        aud                            cad  \
# code                                   AUD                            CAD
# alphaCode                              AUD                            CAD
# numericCode                            036                            124
# name                     Australian Dollar                Canadian Dollar
# rate                              1.488046                       1.359484
# date         Fri, 23 Aug 2024 11:57:17 GMT  Fri, 23 Aug 2024 11:57:17 GMT
# inverseRate                       0.672022                       0.735573
#
#                                        cny                            eur  \
# code                                   CNY                            EUR
# alphaCode                              CNY                            EUR
# numericCode                            156                            978
# name                          Chinese Yuan                           Euro
# ...

# %% [markdown]
# # WORKING WITH SQL

# %%
import mysql.connector
import pandas as pd
conn=mysql.connector.connect(host='localhost',user='root',password='',database="world",port=3306)

# %%
#Write all query of SQL here (ALl function apply )

df=pd.read_sql_query("SELECT * FROM city ",conn)
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9088\1857874830.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("SELECT * FROM city ",conn)
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %%
df.shape
# Out:
# (4079, 5)

# %%
#Write all query of SQL here (ALl function apply )
#Remove the warnings
import warnings
warnings.filterwarnings("ignore")
df1=pd.read_sql_query("SELECT * FROM country",conn)
df1.head()
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# ...

# %%
df1.shape
# Out:
# (239, 15)
